# %% [markdown]
# # 01 — Data Preparation
#
# This notebook handles downloading, preprocessing, and organizing the FFHQ dataset
# for training the FSRCNN super-resolution model.
#
# ## Steps
# 1. Download FFHQ dataset (subset of 5,000–10,000 images)
# 2. Organize images into train/validation/test splits (80/10/10)
# 3. Generate LR/HR image pairs via bicubic downscaling
# 4. Visualize sample pairs to verify quality
# 5. Calculate dataset statistics (mean, std) for normalization
# 6. Save preprocessed data to Google Drive for training persistence
#
# ## Environment
# - Runtime: Google Colab (T4 GPU)
# - Storage: Google Drive for data persistence

# %%
# TODO: Mount Google Drive
# TODO: Download FFHQ subset
# TODO: Create train/val/test splits
# TODO: Generate LR/HR pairs
# TODO: Visualize samples
# TODO: Compute dataset statistics
